# %%
# !pip install openai

# %%
from pathlib import Path
from openai import OpenAI
import openai
from openai import OpenAI
api_key = "sk-proj-VSD5cbbhgxShS-"
"UZ8JaMymMDH7K9baLS7d5XniyY37vG8B2oSWeG3Lb1i6MSCtBe6ujEhFxIFfT3BlbkFJexjz4fKLl7fNO7g0EYjOJ9VGsnc4yBdqm6EOKt6o515SZdEtZBYVYFpiV1IjuVXZs7X3L51EcA"

client = openai.OpenAI(api_key=api_key)
speech_file_path = "/content/sample_data/speechnew.mp3"
response = client.audio.speech.create(
    model="tts-1",
    voice="alloy",
    input="Today is a wonderful day to build something people love!",
)
response.stream_to_file(speech_file_path)
# Out:
# /tmp/ipython-input-3653424006.py:14: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(speech_file_path)

# %%
pip install gtts

# %%
from gtts import gTTS
import os
#Inspect the TTS object to find available methods
mytest="Welcome to Google text-to-speech"
language='en'
myobj=gTTS(text=mytest,lang=language,slow=False)
myobj.save("welcome.mp3")
os.system("mpg321 welcome.mp3")
# Out:
# 32512
