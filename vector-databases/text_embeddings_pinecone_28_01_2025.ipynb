# %%
# !pip uninstall pinecone-client -y
# Out:
# WARNING: Skipping pinecone-client as it is not installed.

# %%
# !pip install "pinecone[grpc]"
# Out:
# Requirement already satisfied: pinecone[grpc] in /usr/local/lib/python3.12/dist-packages (7.3.0)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (2025.10.5)
# Requirement already satisfied: googleapis-common-protos>=1.66.0 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (1.71.0)
# Requirement already satisfied: grpcio>=1.59.0 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (1.76.0)
# Requirement already satisfied: lz4>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (4.4.5)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (0.0.7)
# Requirement already satisfied: protobuf<6.0,>=5.29 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (5.29.5)
# Requirement already satisfied: protoc-gen-openapiv2<0.0.2,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (0.0.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from pinecone[grpc]) (2.5.0)
# Requirement already satisfied: packaging<25.0,>=24.2 in /usr/local/lib/python3.12/dist-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone[grpc]) (24.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone[grpc]) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.5.3->pinecone[grpc]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone[grpc]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone[grpc]) (3.11)

# %%
# Import the Pinecone library
from pinecone import Pinecone, ServerlessSpec
import time

# Initialize a Pinecone client with your API key
pc = Pinecone('pcsk_3hSfUv_96Xmr2ZvoaMexESK84mf6NainkG79SPkru9Phyua7ZDSjykXPK9xCNTjEVF8jY4')

# Define a sample dataset where each item has a unique ID and piece of text
data = [
    {"id": "vec1", "text": "Apple is a popular fruit known for its sweetness and crisp texture."},
    {"id": "vec2", "text": "The tech company Apple is known for its innovative products like the iPhone."},
    {"id": "vec3", "text": "Many people enjoy eating apples as a healthy snack."},
    {"id": "vec4", "text": "Apple Inc. has revolutionized the tech industry with its sleek designs and user-friendly interfaces."},
    {"id": "vec5", "text": "An apple a day keeps the doctor away, as the saying goes."},
    {"id": "vec6", "text": "Apple Computer Company was founded on April 1, 1976, by Steve Jobs, Steve Wozniak, and Ronald Wayne as a partnership."}
]

# Convert the text into numerical vectors that Pinecone can index
embeddings = pc.inference.embed(
    model="multilingual-e5-large",
    inputs=[d['text'] for d in data],
    parameters={"input_type": "passage", "truncate": "END"}
)

print(embeddings)
# Out:
# EmbeddingsList(
#   model='multilingual-e5-large',
#   vector_type='dense',
#   data=[
#     {'vector_type': dense, 'values': [0.04931640625, -0.01328277587890625, ..., -0.0196380615234375, -0.010955810546875]},
#     {'vector_type': dense, 'values': [0.032562255859375, -0.027862548828125, ..., -0.0200653076171875, -0.021026611328125]},
#     ... (2 more embeddings) ...,
#     {'vector_type': dense, 'values': [0.0312347412109375, -0.0185699462890625, ..., -0.02996826171875, -0.032989501953125]},
#     {'vector_type': dense, 'values': [0.03955078125, -0.01013946533203125, ..., 0.0011348724365234375, -0.04296875]}
#   ],
#   usage={'total_tokens': 130}
# )
